# %%
import gisutils
import pydrograph
from pydrograph.attributes import streamflow_attributes

# %%
import geopandas as gpd

# %%
shp_path = '/home/jovyan/data/downloads/b832a6c2f96541808444ec9562c5247e/b832a6c2f96541808444ec9562c5247e/data/contents/HUC8_CONUS/HUC8_US.shp'
data_path = '/home/jovyan/data/data/'

# %%
df = gpd.read_file(shp_path)
df.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                                        TNMID  \
# 0     {4CCAA733-584D-4347-A7F3-4E664ADA8B9B}
# 1     {70274AE7-175E-410E-A1BD-C5B4A8E36460}
# 2     {AC101059-1D6E-465C-AF7F-605322DDFBF9}
# 3     {5D59B8DA-E526-405E-926B-5BAD6F6A1EDC}
# 4     {DEFF3DC1-B64A-430C-8815-C649427611CD}
# ...                                      ...
# 2134  {C0BEC8E3-82A7-4794-998D-F21E28EEF6B1}
# 2135  {DD0CE5F3-C034-42E1-A2F6-250A9FC2565B}
# 2136  {D7329A6F-43E1-4D4B-B3BA-8C0801CD5638}
# 2137  {BC466E42-9D7A-4CA4-9B58-7F34F027C1BD}
# 2138  {636C230F-00D4-49D7-BC7C-97E088F534EF}
#
#                                   METASOURCE SOURCEDATA  \
# 0                                       None       None
# 1                                       None       None
# 2                                       None       None
# 3                                       None       None
# 4                                       None       None
# ...                                      ...        ...
# 2134                                    None       None
# 2135                                    None       None
# 2136                                    None       None
# 2137                                    None       None
# 2138  {74113E96-0C19-4C43-98B2-8975FE3AE49E}       None
#
#                    SOURCEORIG SOURCEFEAT    LOADDATE  GNIS_ID   AREAACRES  \
# 0                        None       None  2012-06-11        0  1104144.63
# 1                        None       None  2012-06-11        0   671679.80
# 2                        None       None  2012-06-11        0  1314676.86
# 3                        None       None  2017-09-20        0   932568.32
# 4                        None       None  2012-06-11        0   650998.70
# ...                       ...        ...         ...      ...         ...
# 2134                     None       None  2016-03-28        0  1575944.88
# 2135                     None       None  2012-06-11        0  1362843.59
# 2136                     None       None  2017-04-07        0  1321215.92
# 2137                     None       None  2014-03-12        0   670886.11
# 2138  Natural Resource Canada       None  2017-05-08        0   797880.41
#
#       AREASQKM    STATES      HUC8                     NAME  Shape_Leng  \
# 0      4468.32     CO,NM  11080001      Canadian Headwaters    3.943636
# 1      2718.19        NM  11080002                 Cimarron    3.006890
# 2      5320.31        NM  11080003           Upper Canadian    6.201702
# 3      3773.97        NM  11080004                     Mora    4.275086
# 4      2634.50        NM  11080005                  Conchas    3.228884
# ...        ...       ...       ...                      ...         ...
# 2134   6377.63  CN,MN,ND  09020311               Middle Red   12.338414
# 2135   5515.24  MN,ND,SD  07020001          Upper Minnesota    7.191060
# 2136   5346.78     CN,MN  09020314                   Roseau    7.392520
# 2137   2714.98        MN  09020304                    Thief    3.216966
# 2138   3228.91        CN  09020318  Rat River-Tourond Creek    4.443277
#
#       Shape_Area                                           geometry
# 0       0.450856  POLYGON ((-104.18034 36.92065, -104.18082 36.9...
# 1       0.273469  POLYGON ((-104.49909 36.32423, -104.49957 36.3...
# 2       0.531733  POLYGON ((-104.21278 35.94052, -104.21295 35.9...
# 3       0.376770  POLYGON ((-105.18148 36.34119, -105.18215 36.3...
# 4       0.261226  POLYGON ((-104.81254 35.64952, -104.81220 35.6...
# ...          ...                                                ...
# 2134    0.782879  POLYGON ((-97.13206 49.87813, -97.13159 49.878...
# 2135    0.633310  POLYGON ((-97.16067 45.95853, -97.16019 45.958...
# 2136    0.656249  POLYGON ((-97.05241 49.24424, -97.05239 49.244...
# 2137    0.329257  POLYGON ((-95.94852 48.56142, -95.94879 48.559...
# 2138    0.399892  POLYGON ((-96.97390 49.70229, -96.97325 49.702...
#
# [2139 rows x 15 columns]

# %%
df[df['STATES']=='OR']
# Out:
#                                        TNMID METASOURCE SOURCEDATA SOURCEORIG  \
# 997   {C20B007A-FBEB-46C5-8F10-A55A6A3B3A22}       None       None       None
# 998   {7ED9F4AC-4F02-42D2-98B3-8B2B67BF6755}       None       None       None
# 999   {AFD8B13C-10BB-458A-8A57-14277AEDCBA3}       None       None       None
# 1101  {3150DB02-A70A-4CBA-8C70-9155B951F92E}       None       None       None
# 1214  {64FB5D5D-6887-44F7-AE09-89BDAB52E888}       None       None       None
# ...                                      ...        ...        ...        ...
# 1396  {277439DC-1C60-4E86-B2EF-AC9CFBDEEF98}       None       None       None
# 1397  {E32AE57C-5F9A-463E-B0CE-BD6D25731C39}       None       None       None
# 1398  {9D4DB191-DF7E-4F11-86ED-12180B663C8A}       None       None       None
# 1399  {357FF255-DB92-4C44-9911-3B8FC218FD59}       None       None       None
# 1443  {479E2930-CB29-445E-B6E7-1456DEE4C05F}       None       None       None
#
#      SOURCEFEAT    LOADDATE  GNIS_ID   AREAACRES  AREASQKM STATES      HUC8  \
# 997        None  2012-06-11        0   920691.02   3725.91     OR  18010201
# 998        None  2012-06-11        0  1030656.11   4170.92     OR  18010202
# 999        None  2012-06-11        0   463358.54   1875.15     OR  18010203
# 1101       None  2013-01-18        0   607043.30   2456.62     OR  17050117
# 1214       None  2017-11-22        0   202494.43    819.47     OR  17100201
# ...         ...         ...      ...         ...       ...    ...       ...
# 1396       None  2017-11-06        0   493870.23   1998.62     OR  17090008
# 1397       None  2013-01-18        0   560310.72   2267.50     OR  17090009
# 1398       None  2013-01-18        0   453672.90   1835.95     OR  17090010
# 1399       None  2013-01-18        0   603343.35   2441.65     OR  17090011
# 1443       None  2017-08-25        0   260249.10   1053.19     OR  17090012
#
#                     NAME  Shape_Leng  Shape_Area  \
# 997           Williamson    4.482972    0.410933
# 998              Sprague    4.944516    0.457253
# 999   Upper Klamath Lake    3.104636    0.205373
# 1101       Lower Malheur    3.893967    0.274750
# 1214           Necanicum    2.075525    0.095066
# ...                  ...         ...         ...
# 1396             Yamhill    3.113865    0.228713
# 1397     Molalla-Pudding    2.581402    0.258975
# 1398            Tualatin    2.920881    0.211497
# 1399           Clackamas    3.714652    0.279201
# 1443    Lower Willamette    2.847682    0.121526
#
#                                                geometry
# 997   POLYGON ((-121.56009 43.29247, -121.55958 43.2...
# 998   POLYGON ((-120.74751 42.67360, -120.74709 42.6...
# 999   POLYGON ((-121.82464 42.44765, -121.82473 42.4...
# 1101  POLYGON ((-117.16048 43.91663, -117.16044 43.9...
# 1214  POLYGON ((-123.69943 45.92734, -123.69950 45.9...
# ...                                                 ...
# 1396  POLYGON ((-123.12636 45.38006, -123.12669 45.3...
# 1397  POLYGON ((-122.45105 45.24959, -122.45000 45.2...
# 1398  POLYGON ((-123.04745 45.79377, -123.04716 45.7...
# 1399  POLYGON ((-122.28691 45.44360, -122.28697 45.4...
# 1443  POLYGON ((-122.41255 45.56099, -122.41205 45.5...
#
# [61 rows x 15 columns]

# %%
import contextily as ctx
url = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}'

# %%
h2o = df[df['NAME']=='Clackamas']
print('crs=',h2o.crs)
h2o.plot()
# Out:
# crs= epsg:4326
# <AxesSubplot:>

# %%
ax = h2o.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax,crs='EPSG:4326', source=url)

# %%
h2o.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
h2o.to_file(data_path+'clack.shp')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import fiona
from shapely.geometry import Point, shape
from gisutils import df2shp, project
from pydrograph import Nwis

# %%
shp_path = '/home/jovyan/data/downloads/shape/WBDHU2.shp'
h2o = gpd.read_file(shp_path)
print('crs=',h2o.crs)
h2o.plot()
# Out:
# crs= epsg:4269
# <AxesSubplot:>

# %%
ax = h2o.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax,crs='EPSG:4326', source=url)

# %%
shp = data_path+'clack.shp'
nwis = Nwis(extent=shp)
# Out:
# reading extent from /home/jovyan/data/data/clack.shp...
# reprojecting extent from +init=epsg:4326 to +proj=longlat +ellps=GRS80 +datum=NAD83 +no_defs
# /home/jovyan/data/conda-envs/pydrograph/lib/python3.8/site-packages/pydrograph-0.post50.dev0+g60b6d04-py3.8.egg/pydrograph/nwis.py:163: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   g = shape(shp.next()['geometry'])
# /home/jovyan/data/conda-envs/pydrograph/lib/python3.8/site-packages/pyproj/crs/crs.py:280: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(projparams)

# %%
gw_field_sites = nwis.get_siteinfo('gwlevels')
# Out:
# getting site inventory for gwlevels...
# url: http://nwis.waterdata.usgs.gov/usa/nwis/gwlevels?nw_longitude_va=-122.609&nw_latitude_va=45.456&se_longitude_va=-121.651&se_latitude_va=44.800&coordinate_format=decimal_degrees&group_key=NONE&format=sitefile_output&sitefile_output_format=rdb&column_name=site_no&column_name=station_nm&column_name=site_tp_cd&column_name=dec_lat_va&column_name=dec_long_va&column_name=coord_meth_cd&column_name=coord_acy_cd&column_name=coord_datum_cd&column_name=dec_coord_datum_cd&column_name=district_cd&column_name=state_cd&column_name=county_cd&column_name=country_cd&column_name=land_net_ds&column_name=map_nm&column_name=map_scale_fc&column_name=alt_va&column_name=alt_meth_cd&column_name=alt_acy_va&column_name=alt_datum_cd&column_name=huc_cd&column_name=basin_cd&column_name=topo_cd&column_name=data_types_cd&column_name=instruments_cd&column_name=construction_dt&column_name=inventory_dt&column_name=tz_cd&column_name=local_time_fg&column_name=reliability_cd&column_name=gw_file_cd&column_name=nat_aqfr_cd&column_name=aqfr_cd&column_name=aqfr_type_cd&column_name=well_depth_va&column_name=hole_depth_va&column_name=depth_src_cd&column_name=project_no&column_name=rt_bol&column_name=peak_begin_date&column_name=peak_end_date&column_name=peak_count_nu&column_name=qw_begin_date&column_name=qw_end_date&column_name=qw_count_nu&column_name=gw_begin_date&column_name=gw_end_date&column_name=gw_count_nu&column_name=sv_begin_date&column_name=sv_end_date&column_name=sv_count_nu&date_format=YYYY-MM-DD&rdb_compression=file&list_of_search_criteria=lat_long_bounding_box
# reading data with pandas...
# finished in 2.00s
#
# culling 165 sites to those within extent...
# finished inventory in 2.21s

# %%
gw_field_sites
# Out:
#                          site_no             station_nm site_tp_cd  \
# site_no
# 450857121443501  450857121443501         05S/08E-11DAA1         GW
# 451241122183601  451241122183601         04S/04E-22BBC3         GW
# 451242122183601  451242122183601         04S/04E-22BBC2         GW
# 451528122253301  451528122253301          04S/03E-03BAA         GW
# 451532122205801  451532122205801          04S/04E-05BBB         GW
# ...                          ...                    ...        ...
# 452652122212801  452652122212801          01S/04E-30DCD         GW
# 452652122283901  452652122283901  01.00S/03.00E-30DDC01         GW
# 452655122202601  452655122202601          01S/04E-29DCC         GW
# 452702122184601  452702122184601          01S/04E-28DDB         GW
# 452706122291201  452706122291201  01.00S/03.00E-30CAD01         GW
#
#                  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  \
# site_no
# 450857121443501   45.149007  -121.744243             M            S
# 451241122183601   45.211232  -122.311194             M            F
# 451242122183601   45.211396  -122.311189             G            5
# 451528122253301   45.257497  -122.427061             M            S
# 451532122205801   45.258732  -122.350640             M            S
# ...                     ...          ...           ...          ...
# 452652122212801   45.447621  -122.358978             M            S
# 452652122283901   45.447665  -122.478743             G            5
# 452655122202601   45.448454  -122.341756             M            S
# 452702122184601   45.450398  -122.313978             M            S
# 452706122291201   45.451551  -122.487926             G            5
#
#                 coord_datum_cd dec_coord_datum_cd  district_cd  ...  \
# site_no                                                         ...
# 450857121443501          NAD27              NAD83           41  ...
# 451241122183601          NAD27              NAD83           41  ...
# 451242122183601          NAD27              NAD83           41  ...
# 451528122253301          NAD27              NAD83           41  ...
# 451532122205801          NAD27              NAD83           41  ...
# ...                        ...                ...          ...  ...
# 452652122212801          NAD27              NAD83           41  ...
# 452652122283901          NAD27              NAD83           41  ...
# 452655122202601          NAD27              NAD83           41  ...
# 452702122184601          NAD27              NAD83           41  ...
# 452706122291201          NAD27              NAD83           41  ...
#
#                  qw_begin_date  qw_end_date qw_count_nu gw_begin_date  \
# site_no
# 450857121443501     1985-06-13   1985-06-13           1    1970-06-07
# 451241122183601     1996-11-18   1996-11-18           1    1995-07-10
# 451242122183601             --           --           0    1993-01-12
# 451528122253301             --           --           0    1967-10-07
# 451532122205801             --           --           0    1972-02-26
# ...                        ...          ...         ...           ...
# 452652122212801             --           --           0    1980-08-22
# 452652122283901             --           --           0    1986-09-29
# 452655122202601             --           --           0    1987-08-14
# 452702122184601             --           --           0    1976-03-26
# 452706122291201             --           --           0    1994-04-26
#
#                 gw_end_date  gw_count_nu  sv_begin_date sv_end_date  \
# site_no
# 450857121443501  1985-06-13            2             --          --
# 451241122183601  1998-08-20           12             --          --
# 451242122183601  1998-08-20           13             --          --
# 451528122253301  1967-10-07            1             --          --
# 451532122205801  1972-02-26            1             --          --
# ...                     ...          ...            ...         ...
# 452652122212801  1988-10-05           29             --          --
# 452652122283901  2004-08-12            2             --          --
# 452655122202601  1988-10-04           12             --          --
# 452702122184601  1976-03-26            1             --          --
# 452706122291201  2004-08-13            2             --          --
#
#                  sv_count_nu                          geometry
# site_no
# 450857121443501            0   POINT (-121.7442435 45.1490071)
# 451241122183601            0   POINT (-122.3111945 45.2112322)
# 451242122183601            0  POINT (-122.3111889 45.21139609)
# 451528122253301            0   POINT (-122.427061 45.25749728)
# 451532122205801            0  POINT (-122.3506403 45.25873248)
# ...                      ...                               ...
# 452652122212801            0   POINT (-122.3589782 45.4476206)
# 452652122283901            0  POINT (-122.4787428 45.44766509)
# 452655122202601            0   POINT (-122.3417559 45.4484539)
# 452702122184601            0   POINT (-122.313978 45.45039838)
# 452706122291201            0  POINT (-122.4879263 45.45155116)
#
# [108 rows x 52 columns]

# %%
gdf = gpd.GeoDataFrame(gw_field_sites, geometry='geometry')
ax = h2o.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
gdf.plot(ax=ax, alpha=0.95, color ='c', edgecolor='k')
ctx.add_basemap(ax,crs='EPSG:4326', source=url)

# %%
gw_field_sites
# Out:
#                          site_no             station_nm site_tp_cd  \
# site_no
# 450857121443501  450857121443501         05S/08E-11DAA1         GW
# 451241122183601  451241122183601         04S/04E-22BBC3         GW
# 451242122183601  451242122183601         04S/04E-22BBC2         GW
# 451528122253301  451528122253301          04S/03E-03BAA         GW
# 451532122205801  451532122205801          04S/04E-05BBB         GW
# ...                          ...                    ...        ...
# 452652122212801  452652122212801          01S/04E-30DCD         GW
# 452652122283901  452652122283901  01.00S/03.00E-30DDC01         GW
# 452655122202601  452655122202601          01S/04E-29DCC         GW
# 452702122184601  452702122184601          01S/04E-28DDB         GW
# 452706122291201  452706122291201  01.00S/03.00E-30CAD01         GW
#
#                  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  \
# site_no
# 450857121443501   45.149007  -121.744243             M            S
# 451241122183601   45.211232  -122.311194             M            F
# 451242122183601   45.211396  -122.311189             G            5
# 451528122253301   45.257497  -122.427061             M            S
# 451532122205801   45.258732  -122.350640             M            S
# ...                     ...          ...           ...          ...
# 452652122212801   45.447621  -122.358978             M            S
# 452652122283901   45.447665  -122.478743             G            5
# 452655122202601   45.448454  -122.341756             M            S
# 452702122184601   45.450398  -122.313978             M            S
# 452706122291201   45.451551  -122.487926             G            5
#
#                 coord_datum_cd dec_coord_datum_cd  district_cd  ...  \
# site_no                                                         ...
# 450857121443501          NAD27              NAD83           41  ...
# 451241122183601          NAD27              NAD83           41  ...
# 451242122183601          NAD27              NAD83           41  ...
# 451528122253301          NAD27              NAD83           41  ...
# 451532122205801          NAD27              NAD83           41  ...
# ...                        ...                ...          ...  ...
# 452652122212801          NAD27              NAD83           41  ...
# 452652122283901          NAD27              NAD83           41  ...
# 452655122202601          NAD27              NAD83           41  ...
# 452702122184601          NAD27              NAD83           41  ...
# 452706122291201          NAD27              NAD83           41  ...
#
#                  qw_begin_date  qw_end_date qw_count_nu gw_begin_date  \
# site_no
# 450857121443501     1985-06-13   1985-06-13           1    1970-06-07
# 451241122183601     1996-11-18   1996-11-18           1    1995-07-10
# 451242122183601             --           --           0    1993-01-12
# 451528122253301             --           --           0    1967-10-07
# 451532122205801             --           --           0    1972-02-26
# ...                        ...          ...         ...           ...
# 452652122212801             --           --           0    1980-08-22
# 452652122283901             --           --           0    1986-09-29
# 452655122202601             --           --           0    1987-08-14
# 452702122184601             --           --           0    1976-03-26
# 452706122291201             --           --           0    1994-04-26
#
#                 gw_end_date  gw_count_nu  sv_begin_date sv_end_date  \
# site_no
# 450857121443501  1985-06-13            2             --          --
# 451241122183601  1998-08-20           12             --          --
# 451242122183601  1998-08-20           13             --          --
# 451528122253301  1967-10-07            1             --          --
# 451532122205801  1972-02-26            1             --          --
# ...                     ...          ...            ...         ...
# 452652122212801  1988-10-05           29             --          --
# 452652122283901  2004-08-12            2             --          --
# 452655122202601  1988-10-04           12             --          --
# 452702122184601  1976-03-26            1             --          --
# 452706122291201  2004-08-13            2             --          --
#
#                  sv_count_nu                          geometry
# site_no
# 450857121443501            0   POINT (-121.7442435 45.1490071)
# 451241122183601            0   POINT (-122.3111945 45.2112322)
# 451242122183601            0  POINT (-122.3111889 45.21139609)
# 451528122253301            0   POINT (-122.427061 45.25749728)
# 451532122205801            0  POINT (-122.3506403 45.25873248)
# ...                      ...                               ...
# 452652122212801            0   POINT (-122.3589782 45.4476206)
# 452652122283901            0  POINT (-122.4787428 45.44766509)
# 452655122202601            0   POINT (-122.3417559 45.4484539)
# 452702122184601            0   POINT (-122.313978 45.45039838)
# 452706122291201            0  POINT (-122.4879263 45.45155116)
#
# [108 rows x 52 columns]

# %%
gwdv_sites = nwis.get_siteinfo('gwdv')
# Out:
# getting site inventory for gwdv...
# url: http://nwis.waterdata.usgs.gov/usa/nwis/dv?referred_module=gw&site_tp_cd=GW&nw_longitude_va=-122.609&nw_latitude_va=45.456&se_longitude_va=-121.651&se_latitude_va=44.800&coordinate_format=decimal_degrees&group_key=NONE&format=sitefile_output&sitefile_output_format=rdb&column_name=site_no&column_name=station_nm&column_name=site_tp_cd&column_name=dec_lat_va&column_name=dec_long_va&column_name=coord_meth_cd&column_name=coord_acy_cd&column_name=coord_datum_cd&column_name=dec_coord_datum_cd&column_name=district_cd&column_name=state_cd&column_name=county_cd&column_name=country_cd&column_name=land_net_ds&column_name=map_nm&column_name=map_scale_fc&column_name=alt_va&column_name=alt_meth_cd&column_name=alt_acy_va&column_name=alt_datum_cd&column_name=huc_cd&column_name=basin_cd&column_name=topo_cd&column_name=data_types_cd&column_name=instruments_cd&column_name=construction_dt&column_name=inventory_dt&column_name=tz_cd&column_name=local_time_fg&column_name=reliability_cd&column_name=gw_file_cd&column_name=nat_aqfr_cd&column_name=aqfr_cd&column_name=aqfr_type_cd&column_name=well_depth_va&column_name=hole_depth_va&column_name=depth_src_cd&column_name=project_no&column_name=rt_bol&column_name=peak_begin_date&column_name=peak_end_date&column_name=peak_count_nu&column_name=qw_begin_date&column_name=qw_end_date&column_name=qw_count_nu&column_name=gw_begin_date&column_name=gw_end_date&column_name=gw_count_nu&column_name=sv_begin_date&column_name=sv_end_date&column_name=sv_count_nu&date_format=YYYY-MM-DD&rdb_compression=file&list_of_search_criteria=lat_long_bounding_box
# reading data with pandas...
# finished in 1.61s
#
# culling 2 sites to those within extent...
# finished inventory in 1.64s

# %%
gwdv_sites
# Out:
#                          site_no     station_nm site_tp_cd  dec_lat_va  \
# site_no
# 452033122195901  452033122195901  02S/04E-29DAD         GW   45.365618
#
#                  dec_long_va coord_meth_cd coord_acy_cd coord_datum_cd  \
# site_no
# 452033122195901  -122.334198             G            5          NAD27
#
#                 dec_coord_datum_cd  district_cd  ...  qw_begin_date  \
# site_no                                          ...
# 452033122195901              NAD83           41  ...             --
#
#                  qw_end_date qw_count_nu gw_begin_date gw_end_date  \
# site_no
# 452033122195901           --           0    1958-05-07  2019-11-01
#
#                  gw_count_nu  sv_begin_date sv_end_date  sv_count_nu  \
# site_no
# 452033122195901          203             --          --            0
#
#                                          geometry
# site_no
# 452033122195901  POINT (-122.3341982 45.36561808)
#
# [1 rows x 52 columns]

# %%
gdf = gpd.GeoDataFrame(gwdv_sites, geometry='geometry')
ax = h2o.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
gdf.plot(ax=ax, color ='r', edgecolor='k')
ctx.add_basemap(ax,crs='EPSG:4326', source=url)

# %%
sites = gwdv_sites.site_no.tolist()
sites
# Out:
# [452033122195901]

# %%
dvs = nwis.get_all_dvs(sites, 'gwlevels', start_date='1990-01-01')
dvs.keys()
# Out:
# http://waterservices.usgs.gov/nwis/dv/?format=rdb&sites=452033122195901&startDT=1990-01-01&parameterCd=72019
# dict_keys([452033122195901])

# %%
dvs[452033122195901]
# Out:
#            agency_cd          site_no    datetime  116034_72019_00003  \
# datetime
# 2001-09-07      USGS  452033122195901  2001-09-07               63.97
# 2001-09-08      USGS  452033122195901  2001-09-08               63.84
# 2001-09-09      USGS  452033122195901  2001-09-09               63.70
# 2001-09-10      USGS  452033122195901  2001-09-10               63.85
# 2001-09-11      USGS  452033122195901  2001-09-11               63.95
# ...              ...              ...         ...                 ...
# 2020-08-27      USGS  452033122195901  2020-08-27               67.23
# 2020-08-28      USGS  452033122195901  2020-08-28               67.21
# 2020-08-29      USGS  452033122195901  2020-08-29               67.26
# 2020-08-30      USGS  452033122195901  2020-08-30               67.29
# 2020-08-31      USGS  452033122195901  2020-08-31               67.18
#
#            116034_72019_00003_cd
# datetime
# 2001-09-07                     A
# 2001-09-08                     A
# 2001-09-09                     A
# 2001-09-10                     A
# 2001-09-11                     A
# ...                          ...
# 2020-08-27                     P
# 2020-08-28                     P
# 2020-08-29                     P
# 2020-08-30                     P
# 2020-08-31                     P
#
# [6915 rows x 5 columns]

# %%
dvs[452033122195901]['116034_72019_00003'].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
